# %%
import pandas as pd

# %%
df_travel = pd.read_csv(r"E:\LavanyaS\travel_complete.csv")
df_travel
# Out:
#       Unnamed: 0         link  \
# 0              0  UWKhvzdnctY
# 1              1  UWKhvzdnctY
# 2              2  VoBBHAw4EuU
# 3              3  CyGb1CQ5vj8
# 4              4  DiTfrDRjo_Y
# ...          ...          ...
# 3598        3598    EzlP02e37
# 3599        3599  xtmvFDo2PWI
# 3600        3600   PdTvFIJOzZ
# 3601        3601  q-elUn0t6CE
# 3602        3602   G_yha2Svt0
#
#                                                   title  \
# 0     15 Best Countries to Visit in Asia - Travel Video
# 1     15 Best Countries to Visit in Asia - Travel Video
# 2        25 Best Cities to Visit in Asia - Travel Video
# 3          How to Travel Southeast Asia on $500 / Month
# 4     The 31-Day South East Asia Backpacking Adventu...
# ...                                                 ...
# 3598  Passing Out Free Books To Students & First Cla...
# 3599  Mary Hart Presents The Oceania Cruises Experience
# 3600                 Sydney Vacation Travel Video Guide
# ...

# %%
df_sc = pd.read_csv(r"E:\LavanyaS\science.csv")
df_science = df_sc.iloc[:,[0,2,3,4,5,6]]
df_science
# Out:
#       Unnamed: 0         link  \
# 0              0   U8X-fd_zQQ
# 1              1  EST1A1BleI4
# 2              2  VoLZXXQL-YY
# 3              3    4tcAZj4Bk
# 4              4  8L5NzdL9BK8
# ...          ...          ...
# 3991        3991   zZXFc0nLsd
# 3992        3992  gTaViQhljn8
# 3993        3993  8Aa9_6ahO48
# 3994        3994  1XnFnUONr9k
# 3995        3995    nM6Rzcv58
#
#                                                   title  \
# 0     12 Cool Science Tricks That Will Make Your Fri...
# 1     7 Amazing Smoke Experiments At Home || Easy Sc...
# 2     9 Incredible Science Facts You Probably Didn't...
# 3      THE TWIST | EP 06 - WAR OF SCIENCE | Angry Prash
# 4     GENERAL SCIENCE/विज्ञान #LIVE CLASS FOR RAILWA...
# ...                                                 ...
# 3991  21 amazing mind blowing psychology facts /21 a...
# 3992           Marxist Critique of Empirical Psychology
# 3993  How computational modeling can force theory bu...
# ...

# %%
df_history = pd.read_csv(r"E:\LavanyaS\history.csv")
df_history
# Out:
#       Unnamed: 0         link  \
# 0              0  2L7SzikqM5A
# 1              1   kzP2N-BMhI
# 2              2  kxaVxz-cmhA
# 3              3   07T1OojiMM
# 4              4  Vn5JxzCzZ5g
# ...          ...          ...
# 3610        3610    UnvQDhWe4
# 3611        3611  J1ymPF7eB-8
# 3612        3612  g0HjNb8fBMA
# 3613        3613  3qA26nB6oIY
# 3614        3614  H6d0Emmz9A4
#
#                                                   title  \
# 0        History of American Political Parties (Part 1)
# 1     CHINESE POLITICS EXPLAINED SIMPLY || WHY IS CH...
# 2              History of The United States Documentary
# 3     எம்.ஜி.ஆர் முதல்வரான கதை | MGR's Political Lif...
# 4     भारत का संविधान - Indian Government + Politics...
# ...                                                 ...
# 3610  Prescription Vibrator - Old Treatment Methods....
# 3611        A sex demon - Rasputin. History Uncensored.
# 3612  Khajuraho Group Of Monuments | History of The ...
# ...

# %%
df_food = pd.read_csv(r"E:\LavanyaS\food.csv")
df_food = df_food.iloc[:,[0,2,3,4,5,6]]
df_food
# Out:
#       Unnamed: 0         link  \
# 0              0   _4aS5vXNLV
# 1              1  l1dDw4wk1E8
# 2              2  k9oV97JEvTk
# 3              3   l6kZjzC9TY
# 4              4  f-rZDXNVBzA
# ...          ...          ...
# 3518        3518  -EkhosE-21I
# 3519        3519   TrRkihFiIJ
# 3520        3520  8j4wLRGqtaU
# 3521        3521    809adYM_I
# 3522        3522  q1fHFULVk5M
#
#                                                   title  \
# 0     EXOTIC FOOD RECIPES YOU'LL WANT TO TRY || 5-Mi...
# 1     Potato Tawa Sandwich Recipe in Hindi by Indian...
# 2     35 DELICIOUS RECIPES YOU CAN COOK UNDER 5 MINUTES
# 3     6 must try mumbai steet food recipes | bombay ...
# 4     IMPROVE YOUR BREAKFAST WITH THESE 25 FOOD RECIPES
# ...                                                 ...
# 3518  AFRICAN FOOD MUKBANG | SEMOLINA AND OGBONO SOU...
# 3519  Gigantic bowl of fufu with different types of ...
# 3520   Fufu mukbang(African food). Eating with my hands
# ...

# %%
df_artndance = pd.read_csv(r"E:\LavanyaS\artndance.csv")
df_artndance = df_artndance.iloc[:,[0,2,3,4,5,6]]
df_artndance
# Out:
#       Unnamed: 0         link  \
# 0              0   C78Ro6E_Pz
# 1              1  X9Fx9fxhNJQ
# 2              2  IYHjrZ1waYE
# 3              3  IL0lL5hzI8A
# 4              4  AE7WXJCDd5k
# ...          ...          ...
# 3234        3234    BiC1qEGYP
# 3235        3235  ixo4FFld0x0
# 3236        3236  ANPYx4H_pkU
# 3237        3237  1mkh9i8x_fA
# 3238        3238   glQHb_yBgi
#
#                                                   title  \
# 0                        INSPIRING ART HACKS AND CRAFTS
# 1     Easy Origami Paper Pen | Paper Craft | DIY Ori...
# 2     Best Out Of Waste Matchbox | Matchbox Reuse Cr...
# 3     2 Awesome Wall Decoration Ideas | Best out of ...
# 4                     16 ART HACKS YOU WILL REALY ENJOY
# ...                                                 ...
# 3234  Mor bhabonare ki haway| Rabindra Nritya Dance ...
# 3235  Dance Raja Dance -- ಡಾನ್ಸ್ ರಾಜ ಡಾನ್ಸ್|Kannada ...
# 3236  Dance Like / Easy Dance Choreography / Harrdy ...
# ...

# %%
frames = [df_travel, df_science, df_food, df_history, df_artndance]
df = pd.concat(frames, axis=0, join='outer', ignore_index=True,
                            keys=None, levels=None, names=None, verify_integrity=False, copy=True)
df = df.iloc[:,1:]
df
# Out:
#               link                                              title  \
# 0      UWKhvzdnctY  15 Best Countries to Visit in Asia - Travel Video
# 1      UWKhvzdnctY  15 Best Countries to Visit in Asia - Travel Video
# 2      VoBBHAw4EuU     25 Best Cities to Visit in Asia - Travel Video
# 3      CyGb1CQ5vj8       How to Travel Southeast Asia on $500 / Month
# 4      DiTfrDRjo_Y  The 31-Day South East Asia Backpacking Adventu...
# ...            ...                                                ...
# 17971    BiC1qEGYP  Mor bhabonare ki haway| Rabindra Nritya Dance ...
# 17972  ixo4FFld0x0  Dance Raja Dance -- ಡಾನ್ಸ್ ರಾಜ ಡಾನ್ಸ್|Kannada ...
# 17973  ANPYx4H_pkU  Dance Like / Easy Dance Choreography / Harrdy ...
# 17974  1mkh9i8x_fA  Style Telugu Full Movie | Lawrence, Prabhu Dev...
# 17975   glQHb_yBgi  Sexy desi Girl dance on Haseeno Ka Deewana Son...
#
#                                              description  \
# 0      Check out all the places seen in this video: h...
# ...

# %%
df.to_csv("E:\LavanyaS\dataset.csv")
